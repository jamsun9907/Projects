# %%
from itertools import chain
from pymongo import MongoClient
import pymysql
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def load_Mongo_recipe():
    """
    MongoDB에 있는 모든 레시피를 불러와 리스트 형태로 반환한다.
    """
    # 커넥션 접속 작업
    HOST = 'cluster0.1lslter.mongodb.net'
    USER = 'Sunyoung'
    PASSWORD = 'sun123'
    DATABASE_NAME = 'recipe_DB'
    COLLECTION_NAME = 'recipe_info_v2'
    MONGO_URI = f"mongodb+srv://{USER}:{PASSWORD}@{HOST}/{DATABASE_NAME}?retryWrites=true&w=majority"

    client = MongoClient(MONGO_URI) 
    db = client[DATABASE_NAME] # Connection
    collection = db[COLLECTION_NAME] # Creating table

    ## MongoDB 에서 데이터 불러오기
    data_list = [i for i in collection.find()]

    return data_list

# %%
def list_to_dataframe(data_list):
    """
    list를 넣어주면 더블리스트 풀고 df에 추가한다.
    Mongo DB에 있던 중복치 처리는 덤
    """
    # 데이터 프래임 생성
    df = pd.DataFrame(
    {'Recipe_name':[],
    'Hit_num':[],
    'Serves':[],
    'Cooking_time':[],
    'Level':[],
    'Url':[],
    'Ingredients':[]})

    for row in range(len(data_list)):
        # 재료의 더블 리스트롤 풀어준다
        dict_val = data_list[row]['ingredients'].values()
        ingredients = ','.join(s for s in list(chain(*dict_val))) # 리스트를 텍스트로 변환

        # 데이터 프레임에 추가 (id, name, url, ingredient 순서)
        df.loc[row] = [
            data_list[row]['recipe_name'], 
            data_list[row]['hit_num'],
            data_list[row]['serves'],
            data_list[row]['cooking_time'], 
            data_list[row]['level'],
            data_list[row]['url'], 
            ingredients]

    return df

# %%
def preprocessing(df):
    """
    깔끔하게 전처리를 완료하는 함수이다.
    """
    df_clean = df.copy()

    # 중복 제거 및 재정렬
    df_clean = df.copy()
    df_clean.drop_duplicates(subset='Url', inplace = True)
    df_clean.reset_index(inplace = True, drop = True)

    # 컬럼 형식 맞추기
    df_clean['Hit_num'] = df_clean['Hit_num'].str.replace(',','').astype(int)
    df_clean['Serves'] = df_clean['Serves'].str.extract(r'(\d+)').astype(int)
    df_clean['Cooking_time'] = df_clean['Cooking_time'].str.replace('2시간','120').str.extract(r'(\d+)').astype(int)

    return df_clean

# %%
# 정제된 레시피 목록을 localDB에 저장한다.
def get_connection():

    HOST = 'localhost'
    USER = 'sunyoung'
    PASSWORD = '0720'
    DB_name='recipe'

    conn = pymysql.connect(host = HOST, user = USER, password = PASSWORD, db = DB_name, charset='utf8') 
    return conn

def init_table(conn):
    """
    recipe Table을 초기화
    """
    cur = conn.cursor()

    cur.execute("DROP TABLE IF EXISTS recipe;")
    cur.execute("""CREATE TABLE recipe (
        id INTEGER NOT NULL AUTO_INCREMENT PRIMARY KEY,
        Recipe_name VARCHAR(200),
        Hit_num INTEGER,
        Serves INTEGER,
        Cooking_time INTEGER,
        Level VARCHAR(200),
        Url VARCHAR(1000),
        Ingredients VARCHAR(1000));""")
    
    conn.commit()
    pass

def df_to_sql(conn, df_clean):
    """
    레시피 데이터 프레임을 Mysql에 저장
    """
    cur = conn.cursor()
    query = "INSERT INTO recipe(Recipe_name, Hit_num, Serves, Cooking_time, Level, Url, Ingredients) VALUES (%s,%s,%s,%s,%s,%s,%s);"

    for row in range(len(df_clean)):
        data = df_clean.iloc[row, :].tolist()
        cur.execute(query, data)
        print(row,'행 까지 완료')
    conn.commit()
    pass

# %% [markdown]
# ### Test

# %%
## MongoDB 에서 데이터 불러오기
data_list = load_Mongo_recipe()

# Mongo DB의 데이터를 df로 변환 후 전처리
df_clean = list_to_dataframe(data_list)
df = preprocessing(df_clean)

# %%
# DB 저장
conn = get_connection() # 커넥션 가져옴
init_table(conn) # 초기화
df_to_sql(conn, df)
# Out:
# 0 행 까지 완료
# 1 행 까지 완료
# 2 행 까지 완료
# 3 행 까지 완료
# 4 행 까지 완료
# 5 행 까지 완료
# 6 행 까지 완료
# 7 행 까지 완료
# 8 행 까지 완료
# 9 행 까지 완료
# 10 행 까지 완료
# 11 행 까지 완료
# 12 행 까지 완료
# 13 행 까지 완료
# 14 행 까지 완료
# 15 행 까지 완료
# 16 행 까지 완료
# 17 행 까지 완료
# 18 행 까지 완료
# 19 행 까지 완료
# 20 행 까지 완료
# 21 행 까지 완료
# 22 행 까지 완료
# 23 행 까지 완료
# 24 행 까지 완료
# 25 행 까지 완료
# 26 행 까지 완료
# 27 행 까지 완료
# 28 행 까지 완료
# 29 행 까지 완료
# 30 행 까지 완료
# 31 행 까지 완료
# 32 행 까지 완료
# 33 행 까지 완료
# 34 행 까지 완료
# 35 행 까지 완료
# 36 행 까지 완료
# 37 행 까지 완료
# 38 행 까지 완료
# 39 행 까지 완료
# 40 행 까지 완료
# 41 행 까지 완료
# 42 행 까지 완료
# 43 행 까지 완료
# 44 행 까지 완료
# 45 행 까지 완료
# 46 행 까지 완료
# 47 행 까지 완료
# 48 행 까지 완료
# 49 행 까지 완료
# 50 행 까지 완료
# 51 행 까지 완료
# 52 행 까지 완료
# 53 행 까지 완료
# 54 행 까지 완료
# 55 행 까지 완료
# 56 행 까지 완료
# 57 행 까지 완료
# 58 행 까지 완료
# 59 행 까지 완료
# 60 행 까지 완료
# 61 행 까지 완료
# 62 행 까지 완료
# 63 행 까지 완료
# 64 행 까지 완료
# 65 행 까지 완료
# 66 행 까지 완료
# 67 행 까지 완료
# 68 행 까지 완료
# 69 행 까지 완료
# 70 행 까지 완료
# 71 행 까지 완료
# 72 행 까지 완료
# 73 행 까지 완료
# 74 행 까지 완료
# 75 행 까지 완료
# 76 행 까지 완료
# 77 행 까지 완료
# 78 행 까지 완료
# 79 행 까지 완료
# 80 행 까지 완료
# 81 행 까지 완료
# 82 행 까지 완료
# 83 행 까지 완료
# 84 행 까지 완료
# 85 행 까지 완료
# 86 행 까지 완료
# 87 행 까지 완료
# 88 행 까지 완료
# 89 행 까지 완료
# 90 행 까지 완료
# 91 행 까지 완료
# 92 행 까지 완료
# 93 행 까지 완료
# 94 행 까지 완료
# 95 행 까지 완료
# 96 행 까지 완료
# 97 행 까지 완료
# 98 행 까지 완료
# 99 행 까지 완료
# 100 행 까지 완료
# 101 행 까지 완료
# 102 행 까지 완료
# 103 행 까지 완료
# 104 행 까지 완료
# 105 행 까지 완료
# 106 행 까지 완료
# 107 행 까지 완료
# 108 행 까지 완료
# 109 행 까지 완료
# 110 행 까지 완료
# 111 행 까지 완료
# 112 행 까지 완료
# 113 행 까지 완료
# 114 행 까지 완료
# 115 행 까지 완료
# 116 행 까지 완료
# 117 행 까지 완료
# 118 행 까지 완료
# 119 행 까지 완료
# 120 행 까지 완료
# 121 행 까지 완료
# 122 행 까지 완료
# 123 행 까지 완료
# 124 행 까지 완료
# 125 행 까지 완료
# 126 행 까지 완료
# 127 행 까지 완료
# 128 행 까지 완료
# 129 행 까지 완료
# 130 행 까지 완료
# 131 행 까지 완료
# 132 행 까지 완료
# 133 행 까지 완료
# 134 행 까지 완료
# 135 행 까지 완료
# 136 행 까지 완료
# 137 행 까지 완료
# 138 행 까지 완료
# 139 행 까지 완료
# 140 행 까지 완료
# 141 행 까지 완료
# 142 행 까지 완료
# 143 행 까지 완료
# 144 행 까지 완료
# 145 행 까지 완료
# 146 행 까지 완료
# 147 행 까지 완료
# 148 행 까지 완료
# 149 행 까지 완료
# 150 행 까지 완료
# 151 행 까지 완료
# 152 행 까지 완료
# 153 행 까지 완료
# 154 행 까지 완료
# 155 행 까지 완료
# 156 행 까지 완료
# 157 행 까지 완료
# 158 행 까지 완료
# 159 행 까지 완료
# 160 행 까지 완료
# 161 행 까지 완료
# 162 행 까지 완료
# 163 행 까지 완료
# 164 행 까지 완료
# 165 행 까지 완료
# 166 행 까지 완료
# 167 행 까지 완료
# 168 행 까지 완료
# 169 행 까지 완료
# 170 행 까지 완료
# 171 행 까지 완료
# 172 행 까지 완료
# 173 행 까지 완료
# 174 행 까지 완료
# 175 행 까지 완료
# 176 행 까지 완료
# 177 행 까지 완료
# 178 행 까지 완료
# 179 행 까지 완료
# 180 행 까지 완료
# 181 행 까지 완료
# 182 행 까지 완료
# 183 행 까지 완료
# 184 행 까지 완료
# 185 행 까지 완료
# 186 행 까지 완료
# 187 행 까지 완료
# 188 행 까지 완료
# 189 행 까지 완료
# 190 행 까지 완료
# 191 행 까지 완료
# 192 행 까지 완료
# 193 행 까지 완료
# 194 행 까지 완료
# 195 행 까지 완료
# 196 행 까지 완료
# 197 행 까지 완료
# 198 행 까지 완료
# 199 행 까지 완료
# 200 행 까지 완료
# 201 행 까지 완료
# 202 행 까지 완료
# 203 행 까지 완료
# 204 행 까지 완료
# 205 행 까지 완료
# 206 행 까지 완료
# 207 행 까지 완료
# 208 행 까지 완료
# 209 행 까지 완료
# 210 행 까지 완료
# 211 행 까지 완료
# 212 행 까지 완료
# 213 행 까지 완료
# 214 행 까지 완료
# 215 행 까지 완료
# 216 행 까지 완료
# 217 행 까지 완료
# 218 행 까지 완료
# 219 행 까지 완료
# 220 행 까지 완료
# 221 행 까지 완료
# 222 행 까지 완료
# 223 행 까지 완료
# 224 행 까지 완료
# 225 행 까지 완료
# 226 행 까지 완료
# 227 행 까지 완료
# 228 행 까지 완료
# 229 행 까지 완료
# 230 행 까지 완료
# 231 행 까지 완료
# 232 행 까지 완료
# 233 행 까지 완료
# 234 행 까지 완료
# 235 행 까지 완료
# 236 행 까지 완료
# 237 행 까지 완료
# 238 행 까지 완료
# 239 행 까지 완료
# 240 행 까지 완료
# 241 행 까지 완료
# 242 행 까지 완료
# 243 행 까지 완료
# 244 행 까지 완료
# 245 행 까지 완료
# 246 행 까지 완료
# 247 행 까지 완료
# 248 행 까지 완료
# 249 행 까지 완료
# 250 행 까지 완료
# 251 행 까지 완료
# 252 행 까지 완료
# 253 행 까지 완료
# 254 행 까지 완료
# 255 행 까지 완료
# 256 행 까지 완료
# 257 행 까지 완료
# 258 행 까지 완료
# 259 행 까지 완료
# 260 행 까지 완료
# 261 행 까지 완료
# 262 행 까지 완료
# 263 행 까지 완료
# 264 행 까지 완료
# 265 행 까지 완료
# 266 행 까지 완료
# 267 행 까지 완료
# 268 행 까지 완료
# 269 행 까지 완료
# 270 행 까지 완료
# 271 행 까지 완료
# 272 행 까지 완료
# 273 행 까지 완료
# 274 행 까지 완료
# 275 행 까지 완료
# 276 행 까지 완료
# 277 행 까지 완료
# 278 행 까지 완료
# 279 행 까지 완료
# 280 행 까지 완료
# 281 행 까지 완료
# 282 행 까지 완료
# 283 행 까지 완료
# 284 행 까지 완료
# 285 행 까지 완료
# 286 행 까지 완료
# 287 행 까지 완료
# 288 행 까지 완료
# 289 행 까지 완료
# 290 행 까지 완료
# 291 행 까지 완료
# 292 행 까지 완료
# 293 행 까지 완료
# 294 행 까지 완료
# 295 행 까지 완료
# 296 행 까지 완료
# 297 행 까지 완료
# 298 행 까지 완료
# 299 행 까지 완료
# 300 행 까지 완료
# 301 행 까지 완료
# 302 행 까지 완료
# 303 행 까지 완료
# 304 행 까지 완료
# 305 행 까지 완료
# 306 행 까지 완료
# 307 행 까지 완료
# 308 행 까지 완료
# 309 행 까지 완료
# 310 행 까지 완료
# 311 행 까지 완료
# 312 행 까지 완료
# 313 행 까지 완료
# 314 행 까지 완료
# 315 행 까지 완료
# 316 행 까지 완료
# 317 행 까지 완료
# 318 행 까지 완료
# 319 행 까지 완료
# 320 행 까지 완료
# 321 행 까지 완료
# 322 행 까지 완료
# 323 행 까지 완료
# 324 행 까지 완료
# 325 행 까지 완료
# 326 행 까지 완료
# 327 행 까지 완료
# 328 행 까지 완료
# 329 행 까지 완료
# 330 행 까지 완료
# 331 행 까지 완료
# 332 행 까지 완료
# 333 행 까지 완료
# 334 행 까지 완료
# 335 행 까지 완료
# 336 행 까지 완료
# 337 행 까지 완료
# 338 행 까지 완료
# 339 행 까지 완료
# 340 행 까지 완료
# 341 행 까지 완료
# 342 행 까지 완료
# 343 행 까지 완료
# 344 행 까지 완료
# 345 행 까지 완료
# 346 행 까지 완료
# 347 행 까지 완료
# 348 행 까지 완료
# 349 행 까지 완료
# 350 행 까지 완료
# 351 행 까지 완료
# 352 행 까지 완료
# 353 행 까지 완료
# 354 행 까지 완료
# 355 행 까지 완료
# 356 행 까지 완료
# 357 행 까지 완료
# 358 행 까지 완료
# 359 행 까지 완료
# 360 행 까지 완료
# 361 행 까지 완료
# 362 행 까지 완료
# 363 행 까지 완료
# 364 행 까지 완료
# 365 행 까지 완료
# 366 행 까지 완료
# 367 행 까지 완료
# 368 행 까지 완료
# 369 행 까지 완료
# 370 행 까지 완료
# 371 행 까지 완료
# 372 행 까지 완료
# 373 행 까지 완료
# 374 행 까지 완료
# 375 행 까지 완료
# 376 행 까지 완료
# 377 행 까지 완료
# 378 행 까지 완료
# 379 행 까지 완료
# 380 행 까지 완료
# 381 행 까지 완료
# 382 행 까지 완료
# 383 행 까지 완료
# 384 행 까지 완료
# 385 행 까지 완료
# 386 행 까지 완료
# 387 행 까지 완료
# 388 행 까지 완료
# 389 행 까지 완료
# 390 행 까지 완료
# 391 행 까지 완료
# 392 행 까지 완료
# 393 행 까지 완료
# 394 행 까지 완료
# 395 행 까지 완료
# 396 행 까지 완료
# 397 행 까지 완료
# 398 행 까지 완료
# 399 행 까지 완료
# 400 행 까지 완료
# 401 행 까지 완료
# 402 행 까지 완료
# 403 행 까지 완료
# 404 행 까지 완료
# 405 행 까지 완료
# 406 행 까지 완료
# 407 행 까지 완료
# 408 행 까지 완료
# 409 행 까지 완료
# 410 행 까지 완료
# 411 행 까지 완료
# 412 행 까지 완료
# 413 행 까지 완료
# 414 행 까지 완료
# 415 행 까지 완료
# 416 행 까지 완료
# 417 행 까지 완료
# 418 행 까지 완료
# 419 행 까지 완료
# 420 행 까지 완료
# 421 행 까지 완료
# 422 행 까지 완료
# 423 행 까지 완료
# 424 행 까지 완료
# 425 행 까지 완료
# 426 행 까지 완료
# 427 행 까지 완료
# 428 행 까지 완료
# 429 행 까지 완료
# 430 행 까지 완료
# 431 행 까지 완료
# 432 행 까지 완료
# 433 행 까지 완료
# 434 행 까지 완료
# 435 행 까지 완료
# 436 행 까지 완료
# 437 행 까지 완료
# 438 행 까지 완료
# 439 행 까지 완료
# 440 행 까지 완료
# 441 행 까지 완료
# 442 행 까지 완료
# 443 행 까지 완료
# 444 행 까지 완료
# 445 행 까지 완료
# 446 행 까지 완료
# 447 행 까지 완료
# 448 행 까지 완료
# 449 행 까지 완료
# 450 행 까지 완료
# 451 행 까지 완료
# 452 행 까지 완료
# 453 행 까지 완료
# 454 행 까지 완료
# 455 행 까지 완료
# 456 행 까지 완료
# 457 행 까지 완료
# 458 행 까지 완료
# 459 행 까지 완료
# 460 행 까지 완료
# 461 행 까지 완료
# 462 행 까지 완료
# 463 행 까지 완료
# 464 행 까지 완료
# 465 행 까지 완료
# 466 행 까지 완료
# 467 행 까지 완료
# 468 행 까지 완료
# 469 행 까지 완료
# 470 행 까지 완료
# 471 행 까지 완료
# 472 행 까지 완료
# 473 행 까지 완료
# 474 행 까지 완료
# 475 행 까지 완료
# 476 행 까지 완료
# 477 행 까지 완료
# 478 행 까지 완료
# 479 행 까지 완료
# 480 행 까지 완료
# 481 행 까지 완료
# 482 행 까지 완료
# 483 행 까지 완료
# 484 행 까지 완료
# 485 행 까지 완료
# 486 행 까지 완료
# 487 행 까지 완료
# 488 행 까지 완료
# 489 행 까지 완료
# 490 행 까지 완료
# 491 행 까지 완료
# 492 행 까지 완료
# 493 행 까지 완료
# 494 행 까지 완료
# 495 행 까지 완료
# 496 행 까지 완료
# 497 행 까지 완료
# 498 행 까지 완료
# 499 행 까지 완료
# 500 행 까지 완료
# 501 행 까지 완료
# 502 행 까지 완료
# 503 행 까지 완료
# 504 행 까지 완료
# 505 행 까지 완료
# 506 행 까지 완료
# 507 행 까지 완료
# 508 행 까지 완료
# 509 행 까지 완료
# 510 행 까지 완료
# 511 행 까지 완료
# 512 행 까지 완료
# 513 행 까지 완료
# 514 행 까지 완료
# 515 행 까지 완료
# 516 행 까지 완료
# 517 행 까지 완료
# 518 행 까지 완료
# 519 행 까지 완료
# 520 행 까지 완료
# 521 행 까지 완료
# 522 행 까지 완료
# 523 행 까지 완료
# 524 행 까지 완료
# 525 행 까지 완료
# 526 행 까지 완료
# 527 행 까지 완료
# 528 행 까지 완료
# 529 행 까지 완료
# 530 행 까지 완료
# 531 행 까지 완료
# 532 행 까지 완료
# 533 행 까지 완료
# 534 행 까지 완료
# 535 행 까지 완료
# 536 행 까지 완료
# 537 행 까지 완료
# 538 행 까지 완료
# 539 행 까지 완료
# 540 행 까지 완료
# 541 행 까지 완료
# 542 행 까지 완료
# 543 행 까지 완료
# 544 행 까지 완료
# 545 행 까지 완료
# 546 행 까지 완료
# 547 행 까지 완료
# 548 행 까지 완료
# 549 행 까지 완료
# 550 행 까지 완료
# 551 행 까지 완료
# 552 행 까지 완료
# 553 행 까지 완료
# 554 행 까지 완료
# 555 행 까지 완료
# 556 행 까지 완료
# 557 행 까지 완료
# 558 행 까지 완료
# 559 행 까지 완료
# 560 행 까지 완료
# 561 행 까지 완료
# 562 행 까지 완료
# 563 행 까지 완료
# 564 행 까지 완료
# 565 행 까지 완료
# 566 행 까지 완료
# 567 행 까지 완료
# 568 행 까지 완료
# 569 행 까지 완료
# 570 행 까지 완료
# 571 행 까지 완료
# 572 행 까지 완료
# 573 행 까지 완료
# 574 행 까지 완료
# 575 행 까지 완료
# 576 행 까지 완료
# 577 행 까지 완료
# 578 행 까지 완료
# 579 행 까지 완료
# 580 행 까지 완료
# 581 행 까지 완료
# 582 행 까지 완료
# 583 행 까지 완료
# 584 행 까지 완료
# 585 행 까지 완료
# 586 행 까지 완료
# 587 행 까지 완료
# 588 행 까지 완료
# 589 행 까지 완료
# 590 행 까지 완료
# 591 행 까지 완료
# 592 행 까지 완료
# 593 행 까지 완료
# 594 행 까지 완료
# 595 행 까지 완료
# 596 행 까지 완료
# 597 행 까지 완료
# 598 행 까지 완료
# 599 행 까지 완료
# 600 행 까지 완료
# 601 행 까지 완료
# 602 행 까지 완료
# 603 행 까지 완료
# 604 행 까지 완료
# 605 행 까지 완료
# 606 행 까지 완료
# 607 행 까지 완료
# 608 행 까지 완료
# 609 행 까지 완료
# 610 행 까지 완료
# 611 행 까지 완료
# 612 행 까지 완료
# 613 행 까지 완료
# 614 행 까지 완료
# 615 행 까지 완료
# 616 행 까지 완료
# 617 행 까지 완료
# 618 행 까지 완료
# 619 행 까지 완료
# 620 행 까지 완료
# 621 행 까지 완료
# 622 행 까지 완료
# 623 행 까지 완료
# 624 행 까지 완료
# 625 행 까지 완료
# 626 행 까지 완료
# 627 행 까지 완료
# 628 행 까지 완료
# 629 행 까지 완료
# 630 행 까지 완료
# 631 행 까지 완료
# 632 행 까지 완료
# 633 행 까지 완료
# 634 행 까지 완료
# 635 행 까지 완료
# 636 행 까지 완료
# 637 행 까지 완료
# 638 행 까지 완료
# 639 행 까지 완료
# 640 행 까지 완료
# 641 행 까지 완료
# 642 행 까지 완료
# 643 행 까지 완료
# 644 행 까지 완료
# 645 행 까지 완료
# 646 행 까지 완료
# 647 행 까지 완료
# 648 행 까지 완료
# 649 행 까지 완료
# 650 행 까지 완료
# 651 행 까지 완료
# 652 행 까지 완료
# 653 행 까지 완료
# 654 행 까지 완료
# 655 행 까지 완료
# 656 행 까지 완료
# 657 행 까지 완료
# 658 행 까지 완료
# 659 행 까지 완료
# 660 행 까지 완료
# 661 행 까지 완료
# 662 행 까지 완료
# 663 행 까지 완료
# 664 행 까지 완료
# 665 행 까지 완료
# 666 행 까지 완료
# 667 행 까지 완료
# 668 행 까지 완료
# 669 행 까지 완료
# 670 행 까지 완료
# 671 행 까지 완료
# 672 행 까지 완료
# 673 행 까지 완료
# 674 행 까지 완료
# 675 행 까지 완료
# 676 행 까지 완료
# 677 행 까지 완료
# 678 행 까지 완료
# 679 행 까지 완료
# 680 행 까지 완료
# 681 행 까지 완료
# 682 행 까지 완료
# 683 행 까지 완료
# 684 행 까지 완료
# 685 행 까지 완료
# 686 행 까지 완료
# 687 행 까지 완료
# 688 행 까지 완료
# 689 행 까지 완료
# 690 행 까지 완료
# 691 행 까지 완료
# 692 행 까지 완료
# 693 행 까지 완료
# 694 행 까지 완료
# 695 행 까지 완료
# 696 행 까지 완료
# 697 행 까지 완료
# 698 행 까지 완료
# 699 행 까지 완료
# 700 행 까지 완료
# 701 행 까지 완료
# 702 행 까지 완료
# 703 행 까지 완료
# 704 행 까지 완료
# 705 행 까지 완료
# 706 행 까지 완료
# 707 행 까지 완료
# 708 행 까지 완료
# 709 행 까지 완료
# 710 행 까지 완료
# 711 행 까지 완료
# 712 행 까지 완료
# 713 행 까지 완료
# 714 행 까지 완료
# 715 행 까지 완료
# 716 행 까지 완료
# 717 행 까지 완료
# 718 행 까지 완료
# 719 행 까지 완료
# 720 행 까지 완료
# 721 행 까지 완료
# 722 행 까지 완료
# 723 행 까지 완료
# 724 행 까지 완료
# 725 행 까지 완료
# 726 행 까지 완료
# 727 행 까지 완료
# 728 행 까지 완료
# 729 행 까지 완료
# 730 행 까지 완료
# 731 행 까지 완료
# 732 행 까지 완료
# 733 행 까지 완료
# 734 행 까지 완료
# 735 행 까지 완료
# 736 행 까지 완료
# 737 행 까지 완료
# 738 행 까지 완료
# 739 행 까지 완료
# 740 행 까지 완료
# 741 행 까지 완료
# 742 행 까지 완료
# 743 행 까지 완료
# 744 행 까지 완료
# 745 행 까지 완료
# 746 행 까지 완료
# 747 행 까지 완료
# 748 행 까지 완료
# 749 행 까지 완료
# 750 행 까지 완료
# 751 행 까지 완료
# 752 행 까지 완료
# 753 행 까지 완료
# 754 행 까지 완료
# 755 행 까지 완료
# 756 행 까지 완료
# 757 행 까지 완료
# 758 행 까지 완료
# 759 행 까지 완료
# 760 행 까지 완료
# 761 행 까지 완료
# 762 행 까지 완료
# 763 행 까지 완료
# 764 행 까지 완료
# 765 행 까지 완료
# 766 행 까지 완료
# 767 행 까지 완료
# 768 행 까지 완료
# 769 행 까지 완료
# 770 행 까지 완료
# 771 행 까지 완료
# 772 행 까지 완료
# 773 행 까지 완료
# 774 행 까지 완료
# 775 행 까지 완료
# 776 행 까지 완료
# 777 행 까지 완료
# 778 행 까지 완료
# 779 행 까지 완료
# 780 행 까지 완료
# 781 행 까지 완료
# 782 행 까지 완료
# 783 행 까지 완료
# 784 행 까지 완료
# 785 행 까지 완료
# 786 행 까지 완료
# 787 행 까지 완료
# 788 행 까지 완료
# 789 행 까지 완료
# 790 행 까지 완료
# 791 행 까지 완료
# 792 행 까지 완료
# 793 행 까지 완료
# 794 행 까지 완료
# 795 행 까지 완료
# 796 행 까지 완료
# 797 행 까지 완료
# 798 행 까지 완료
# 799 행 까지 완료
# 800 행 까지 완료
# 801 행 까지 완료
# 802 행 까지 완료
# 803 행 까지 완료
# 804 행 까지 완료
# 805 행 까지 완료
# 806 행 까지 완료
# 807 행 까지 완료
# 808 행 까지 완료
# 809 행 까지 완료
# 810 행 까지 완료
# 811 행 까지 완료
# 812 행 까지 완료
# 813 행 까지 완료
# 814 행 까지 완료
# 815 행 까지 완료
# 816 행 까지 완료
# 817 행 까지 완료
# 818 행 까지 완료
# 819 행 까지 완료
# 820 행 까지 완료
# 821 행 까지 완료
# 822 행 까지 완료
# 823 행 까지 완료
# 824 행 까지 완료
# 825 행 까지 완료
# 826 행 까지 완료
# 827 행 까지 완료
# 828 행 까지 완료
# 829 행 까지 완료
# 830 행 까지 완료
# 831 행 까지 완료
# 832 행 까지 완료
# 833 행 까지 완료
# 834 행 까지 완료
# 835 행 까지 완료
# 836 행 까지 완료
# 837 행 까지 완료
# 838 행 까지 완료
# 839 행 까지 완료
# 840 행 까지 완료
# 841 행 까지 완료
# 842 행 까지 완료
# 843 행 까지 완료
# 844 행 까지 완료
# 845 행 까지 완료
# 846 행 까지 완료
# 847 행 까지 완료
# 848 행 까지 완료
# 849 행 까지 완료
# 850 행 까지 완료
# 851 행 까지 완료
# 852 행 까지 완료
# 853 행 까지 완료
# 854 행 까지 완료
# 855 행 까지 완료
# 856 행 까지 완료
# 857 행 까지 완료
# 858 행 까지 완료
# 859 행 까지 완료
# 860 행 까지 완료
# 861 행 까지 완료
# 862 행 까지 완료
# 863 행 까지 완료
# 864 행 까지 완료
# 865 행 까지 완료
# 866 행 까지 완료
# 867 행 까지 완료
# 868 행 까지 완료
# 869 행 까지 완료
# 870 행 까지 완료
# 871 행 까지 완료
# 872 행 까지 완료
# 873 행 까지 완료
# 874 행 까지 완료
# 875 행 까지 완료
# 876 행 까지 완료
# 877 행 까지 완료
# 878 행 까지 완료
# 879 행 까지 완료
# 880 행 까지 완료
# 881 행 까지 완료
# 882 행 까지 완료
# 883 행 까지 완료
# 884 행 까지 완료
# 885 행 까지 완료
# 886 행 까지 완료
# 887 행 까지 완료
# 888 행 까지 완료
# 889 행 까지 완료
# 890 행 까지 완료
# 891 행 까지 완료
# 892 행 까지 완료
# 893 행 까지 완료
# 894 행 까지 완료
# 895 행 까지 완료
# 896 행 까지 완료
# 897 행 까지 완료
# 898 행 까지 완료
# 899 행 까지 완료
# 900 행 까지 완료
# 901 행 까지 완료
# 902 행 까지 완료
# 903 행 까지 완료
# 904 행 까지 완료
# 905 행 까지 완료
# 906 행 까지 완료
# 907 행 까지 완료
# 908 행 까지 완료
# 909 행 까지 완료
# 910 행 까지 완료
# 911 행 까지 완료
# 912 행 까지 완료
# 913 행 까지 완료
# 914 행 까지 완료
# 915 행 까지 완료
# 916 행 까지 완료
# 917 행 까지 완료
# 918 행 까지 완료
# 919 행 까지 완료
# 920 행 까지 완료
# 921 행 까지 완료
# 922 행 까지 완료
# 923 행 까지 완료
# 924 행 까지 완료
# 925 행 까지 완료
# 926 행 까지 완료
# 927 행 까지 완료
# 928 행 까지 완료
# 929 행 까지 완료
# 930 행 까지 완료
# 931 행 까지 완료
# 932 행 까지 완료
# 933 행 까지 완료
# 934 행 까지 완료
# 935 행 까지 완료
# 936 행 까지 완료
# 937 행 까지 완료
# 938 행 까지 완료
# 939 행 까지 완료
# 940 행 까지 완료
# 941 행 까지 완료
# 942 행 까지 완료
# 943 행 까지 완료
# 944 행 까지 완료
# 945 행 까지 완료
# 946 행 까지 완료
# 947 행 까지 완료
# 948 행 까지 완료
# 949 행 까지 완료
# 950 행 까지 완료
# 951 행 까지 완료
# 952 행 까지 완료
# 953 행 까지 완료
# 954 행 까지 완료
# 955 행 까지 완료
# 956 행 까지 완료
# 957 행 까지 완료
# 958 행 까지 완료
# 959 행 까지 완료
# 960 행 까지 완료
# 961 행 까지 완료
# 962 행 까지 완료
# 963 행 까지 완료
# 964 행 까지 완료
# 965 행 까지 완료
# 966 행 까지 완료
# 967 행 까지 완료
# 968 행 까지 완료
# 969 행 까지 완료
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 df_to_sql(conn, df)
#
# Cell In [5], line 41, in df_to_sql(conn, df_clean)
#      39 for row in range(len(df_clean)):
#      40     data = df_clean.iloc[row, :].tolist()
# ---> 41     cur.execute(query, data)
#      42     print(row,'행 까지 완료')
#      43 conn.commit()
#
# File c:\Users\Sunyoung_Jang\anaconda3\envs\project_3\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File c:\Users\Sunyoung_Jang\anaconda3\envs\project_3\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File c:\Users\Sunyoung_Jang\anaconda3\envs\project_3\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File c:\Users\Sunyoung_Jang\anaconda3\envs\project_3\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     773 else:
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#     777 if result.server_status is not None:
#
# File c:\Users\Sunyoung_Jang\anaconda3\envs\project_3\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1154 def read(self):
#    1155     try:
# -> 1156         first_packet = self.connection._read_packet()
#    1158         if first_packet.is_ok_packet():
#    1159             self._read_ok_packet(first_packet)
#
# File c:\Users\Sunyoung_Jang\anaconda3\envs\project_3\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File c:\Users\Sunyoung_Jang\anaconda3\envs\project_3\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\Users\Sunyoung_Jang\anaconda3\envs\project_3\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# DataError: (1406, "Data too long for column 'Ingredients' at row 1")

# %% [markdown]
# ### 여기 부터 모델링

# %%
def count_tokenizer(text):
    """
    텍스트 전처리를 위한 함수.
    이후 아래 find_sim_recipe 함수에서 CountVectorizer(tokenizer = count_tokenizer) 로 사용한다.
    """
    pass

# %%
def find_sim_recipe(df, my_ingredients_list):
    """
    내가 가진 재료와 비슷한 레시피를 반환한다.
    df : MongoDB로 만든 데이터프래임
    my_ingredients_list : 내가 가진 재료 리스트. 콤마(,)로 구분한 string
    """
    # 내 재료와 레시피 재료 
    my_ingredients = [my_ingredients_list]
    recipe_ingre_list = list(df['Ingredients'])

    doc_list = my_ingredients + recipe_ingre_list
    
    # Embedding
    vect = CountVectorizer(lowercase=False)
    ingredients_mat = vect.fit_transform(doc_list)

    # Cosine similarity
    similarity = cosine_similarity(ingredients_mat[0], ingredients_mat[1:]) # 내 재료, 레시피 재료
    # print(similarity) # 모든 레시피의 유사도를 다 보여줌.

    # 데이터 프레임에 합친 뒤 유사도가 큰 순서로 정렬
    sim = similarity.reshape(-1)
    df['similarity'] = sim

    df_final = df.sort_values(by = 'similarity', ascending = False)

    return df_final

# %% [markdown]
# # 단어 벡터화

# %%
# 너무 당연한 재료는 빼는 함수 구현하기
# 텍스트 전처리

# %%
class recipe_recommender:
    def __init__(my_ingredients):
        self.my_ingredients = my_ingredients

        return my_ingredients

# %%
### 알고리즘 클레스로 구현하기

my_ingredients = '라면, 감자, 소금, 버터, 설탕, 고추장, 밥, 후추, 간장, 당근, 소면, 계란'

df2 = find_sim_recipe(df, my_ingredients)
# 여기 부터 조회수 및 조리시간 필터링을 사용한 추천
recommandation = df2.head(50)
# df2.sort_values(by='Hit_num', ascending = False)


# 쿠킹 타임 이내 필터링 하여 hit 높은 순으로 반환
cooking_time = 30 # 희망 조리 시간: 분 단위로 입력
recommandation = recommandation[recommandation['Cooking_time(min)'] <= cooking_time]
# recommandation = recommandation.sort_values(by='Hit_num', ascending = False)
recommandation.head(10)

# %%
# from sklearn.feature_extraction.text import CountVectorizer

# recipe_ingre_list = list(df['Ingredients'])
# # 두 재료 목록 합치기
# doc_list = [my_ingredients] + recipe_ingre_list

# # 벡터화
# vect = CountVectorizer(lowercase=False)
# ingredients_mat = vect.fit_transform(doc_list)
# print(ingredients_mat.shape)

# # 벡터화 한 결과는 희소 행렬이므로 밀집 행렬로 변환하면 단어 목록을 볼 수 있음
# feature_vect_dense = ingredients_mat.todense()

# print(feature_vect_dense)
# print(vect.vocabulary_) # 단어 모음 볼 수 있는 코드

# ### Todo! vocabulary 보니까 '익은' 뭐 이런 것도 벡터화 되어있음. 전처리 해줘야함

# %% [markdown]
# # 중요한 코드
# - 근데 왜 내 재료 기준으로 백터화 하든 둘다 기준으로 벡터화 하든 유사도는 동일하지? 안 동일 다시 해보니까..

# %%
# 사이킷런 라이브러리 활용 코사인 유사도 계산
# 라이브러리는 먼저 넣는 값을 기준으로 유사도를 계산한다. (따라서 벡터화 할 때 굳이 내 재료만 벡터화 fit할 필요 없음)

from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ingredients_mat[0], ingredients_mat[1:]) # 내 재료, 레시피 재료
# print(similarity) # 모든 레시피의 유사도를 다 보여줌.

# 데이터 프레임에 합친 뒤 유사도가 큰 순서로 정렬하면...
sim = similarity.reshape(-1)

print(similarity.shape)
print(similarity[:2])

df['similarity'] = sim

df_final = df.sort_values(by = 'similarity', ascending = False)
df_final.head(10)
# Todo : 이거 유사도 순서로 보여주는 대시보드 있으면 좋을 듯
