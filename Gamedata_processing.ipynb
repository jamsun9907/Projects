# %% [markdown]
# <a href="https://colab.research.google.com/github/jamsun9907/Projects/blob/main/Gamedata_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction**
# =====
# Start date : 2022.08.24
# > 데이터를 살펴보고 어떠한 데이터인지(사내 데이터, 사외 데이터 크롤링 DB)파악하고 회사 형태를 가정한다.
# ---------------------------------------
#
# 1. **필수 포함 내용**
# - 지역에 따라서 선호하는 게임 장르가 다를까 라는 질문에 대답
# - 연도별 게임의 트렌드가 있을까 라는 질문에 대답
# - 출고량이 높은 게임에 대한 분석 및 시각화 프로세스가 포함
#
# 2. **사전 주요 가정**
# * 사내 데이터인가 사외 데이터인가? -> 사외 데이터로 추정
#    - 사내 데이터라면 매출 추이 확인 가능
#    - 사외 데이터라면 거시적 추세 위주로 탐색
#
#
# * 회사의 형태는? -> 괜찮은 IP 한개 보유한 중견 게임 개발사.
#     * 게임 배급 및 유통사?(like 넥슨) 게임 개발사? (like CD project)
#     * 대기업? 중견? 중소? (네이버, 카카오 게임즈 / 크래프톤, 블루홀 / 게임빌, 그 외 소규모)
#     * 한 장르 주력? 여러 장르 한 IP로 다양하게? (Like 데브시스터즈)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load pakages & Settings

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Ignoring warnings
import warnings
warnings.filterwarnings("ignore")

#-------------------------------------------
pd.options.display.max_rows = None

# %%
# Data acquisition

path = r'/content/drive/MyDrive/0.Data for analysis/Project/vgames2.csv'

raw = pd.read_csv(path, index_col='Unnamed: 0')
print(raw.shape)
# Out:
# (16598, 9)

# %%
raw.sample(10)
# Out:
#                                      Name Platform    Year         Genre  \
# 7757   LEGO Star Wars III: The Clone Wars      PS3  2011.0        Action
# 8722         Hellboy: The Science of Evil      PSP  2008.0        Action
# 7209                        Mario Party 7       GC  2005.0          Misc
# 8706                Tales of Fandom Vol.2      PS2  2007.0  Role-Playing
# 16469     PoPoLoCrois: Hajimari no Bouken      PS2  2002.0  Role-Playing
# 7026                 Euro Truck Simulator       PC  2008.0    Simulation
# 147                             Fallout 4       PC  2015.0  Role-Playing
# 5570                          FIFA Street      PS3  2012.0        Sports
# 13113                     Toukiden Kiwami      PS4  2015.0        Action
# 8869                         Street Hoops       XB  2002.0        Sports
#
#                           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 7757                      LucasArts     0.52     0.49        0         0.2
# 8722   Konami Digital Entertainment     0.04        0        0           0
# 7209                       Nintendo     0.95     0.11     0.46        0.04
# 8706             Namco Bandai Games        0        0     0.08           0
# 16469   Sony Computer Entertainment        0        0     0.16           0
# 7026                     Rondomedia        0     0.42        0        0.09
# 147              Bethesda Softworks      0.5     0.63        0         0.1
# 5570                Electronic Arts     0.11     0.92        0        0.25
# 13113                    Tecmo Koei     0.05     0.07     0.02        0.02
# 8869                     Activision     0.21     0.06        0        0.01

# %% [markdown]
# **Data Preparation**
# ====
#
# ### 1. Handdling Missing value
# - Year   # 271
# - Genre  # 50
# - Publisher # 58 -> 우리의 분석에서 필요한가? 추후 필요하면 추가
#
# ### 2. Duplicates
# - name 중복되는 경우
#
# ### 3. Inaccurate data
#
# **Datatype 변경**
# - Platform, Genre -> Categorical
# - Year -> Int
# - NA~other Sales -> float
#
# **Outlier (이상치 조정)**
# - Year 0~100 처리

# %%
# 분석에 사용할 데이터
df = raw.copy()

# 이름에 따라 데이터 재 정렬
df = df.sort_values(by = 'Name', ascending = True).reset_index(drop = True)

# %% [markdown]
# ## 1. Handdling Missing value

# %% [markdown]
# Genre : 제거
# Year : 일단 제거
# Publisher : 분석에 안쓸 것이므로 결측값은 'Unknown'으로 대채
# * 둘 다 시간 되면 외부데이터를 통해 결측치를 채워 넣는다.

# %%
# Missing value 확인
df.isna().sum()
# Out:
# Name             0
# Platform         0
# Year           271
# Genre           50
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# dtype: int64

# %%
df[df['Genre'].isna() | df['Year'].isna()]
# Out:
#                                              Name Platform  Year  \
# 147        AKB1/48: Idol to Guam de Koishitara...     X360   NaN
# 198                  Action Man-Operation Extreme       PS   NaN
# 214                    Advance Wars: Days of Ruin       DS   NaN
# 217                                     Adventure     2600   NaN
# 250                  Agarest Senki: Re-appearance      PS3   NaN
# ...                                           ...      ...   ...
# 16405              Yu Yu Hakusho: Dark Tournament      PS2   NaN
# 16412  Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii   NaN
# 16498                    Zero: Tsukihami no Kamen      Wii   NaN
# 16568                              eJay Clubworld      PS2   NaN
# 16596                  wwe Smackdown vs. Raw 2006      PS2   NaN
#
#               Genre           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 147            Misc                 NaN        0        0     0.01           0
# 198          Action                 NaN     0.05     0.03        0        0.01
# 214        Strategy            Nintendo     0.44     0.13        0        0.06
# 217       Adventure               Atari     1.21     0.08        0        0.01
# 250    Role-Playing        Idea Factory        0        0     0.01           0
# ...             ...                 ...      ...      ...      ...         ...
# 16405      Fighting                 NaN      0.1     0.08        0        0.03
# 16412        Racing             Unknown        0        0     0.02           0
# 16498        Action            Nintendo        0        0     0.08           0
# 16568          Misc  Empire Interactive     0.07     0.06        0        0.02
# 16596      Fighting                 NaN     1.57     1.02        0        0.41
#
# [321 rows x 9 columns]

# %%
# 결측치 처리
df_clean = df.dropna(subset = ['Genre','Year'])

# 확인
df_clean[df_clean['Genre'].isna() | df_clean['Year'].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %%
# Publisher 결측치 대채
# df[df['Publisher'].isna()]
df_clean = df_clean.replace(np.nan, 'Unknown')

# 확인
df_clean[df_clean['Publisher'].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %% [markdown]
# ## 2. Duplicates

# %%
# duplicates 확인
print(df_clean.shape[0] - df_clean['Name'].nunique()) #중복값 4947개 -> 전처리 후 다시 확인, Handle 하기.
# Out:
# 4947

# %%
df_clean[df_clean.duplicated(subset = ['Name','Platform'], keep = False)]
# Out:
#                              Name Platform    Year   Genre        Publisher  \
# 7712                Madden NFL 13      PS3  2012.0  Sports  Electronic Arts
# 7716                Madden NFL 13      PS3  2012.0  Sports  Electronic Arts
# 9621  Need for Speed: Most Wanted       PC  2012.0  Racing  Electronic Arts
# 9622  Need for Speed: Most Wanted       PC  2005.0  Racing  Electronic Arts
# 9624  Need for Speed: Most Wanted     X360  2005.0  Racing  Electronic Arts
# 9630  Need for Speed: Most Wanted     X360  2012.0  Racing  Electronic Arts
#
#      NA_Sales EU_Sales JP_Sales Other_Sales
# 7712     2.11     0.23        0        0.22
# 7716        0     0.01        0           0
# 9621        0     0.06        0        0.02
# 9622      20K     0.23        0        0.05
# 9624        1     0.17     0.02         0.1
# 9630     0.62      0.8     0.01        0.15

# %% [markdown]
# **중복값을 보면 겹친 두 값 중 주로 후자에 나온 값이 데이터를 더욱 많이 보존하고 있음. 따라서 keep = 'last'로 설정**

# %%
# 진짜 중복값 (Name과 Platform 둘다 동일한 중복값)
df_duplicates = df_clean[df_clean.duplicated(subset = ['Name','Platform'], keep = 'last')] 
print(f'# of duplicates : {df_duplicates.shape[0]}')

# 중복값 저장
df_duplicates
# Out:
# # of duplicates : 3
#                              Name Platform    Year   Genre        Publisher  \
# 7712                Madden NFL 13      PS3  2012.0  Sports  Electronic Arts
# 9621  Need for Speed: Most Wanted       PC  2012.0  Racing  Electronic Arts
# 9624  Need for Speed: Most Wanted     X360  2005.0  Racing  Electronic Arts
#
#      NA_Sales EU_Sales JP_Sales Other_Sales
# 7712     2.11     0.23        0        0.22
# 9621        0     0.06        0        0.02
# 9624        1     0.17     0.02         0.1

# %%
# 중복값 처리
df_clean = df_clean.drop_duplicates(subset = ['Name','Platform'], keep = 'last')

# 최종 확인
df_clean[df_clean.duplicated(subset = ['Name','Platform'], keep = 'last')]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %% [markdown]
# ## 3. Inaccurate data

# %% [markdown]
# ###**Data type transformataion**
# * Year -> int
# * Platform / Genre -> Category
# * Sales -> float (Unit : Million)

# %%
# Dtype 변경 - 이상치 탐색을 위해
# Year
df_clean['Year'] = df_clean['Year'].astype('int')

# Platform / Genre
#df_clean['Platform'] = df_clean['Platform'].astype('category')
df_clean['Genre'] = df_clean['Genre'].astype('category')

# %%
# 이상한 sales 값 찾기
import re

def not_num(a):
  return bool(re.search('[A-z]', a))

error = df['NA_Sales'].apply(not_num)
df['NA_Sales'][error]
# Out:
# 188      0.37M
# 233        60K
# 340      0.22M
# 483        90K
# 552      0.02M
#          ...
# 16340       0M
# 16383      60K
# 16454       0M
# 16464       0M
# 16554    0.14M
# Name: NA_Sales, Length: 200, dtype: object

# %%
# 문자 숫자 대채 함수 (단위: M)

def cleaner(col):

  temp_list = []

  for row in col:
    if bool(re.search('K', row)) == True:
      K = float(row.replace('K','')) * 0.001
      temp_list.append(K)

    elif bool(re.search('M', row)) == True:
      M = float(row.replace('M',''))
      temp_list.append(M)

    else : temp_list.append(float(row))

  return temp_list

# %%
df1 = df_clean.copy()

# 함수 적용
for col in range(5,9): 
  df1.iloc[:,col] = cleaner(df1.iloc[:,col])

# 확인
df1.info()
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16274 entries, 0 to 16597
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16274 non-null  object
#  1   Platform     16274 non-null  object
#  2   Year         16274 non-null  int64
#  3   Genre        16274 non-null  category
#  4   Publisher    16274 non-null  object
#  5   NA_Sales     16274 non-null  float64
#  6   EU_Sales     16274 non-null  float64
#  7   JP_Sales     16274 non-null  float64
#  8   Other_Sales  16274 non-null  float64
# dtypes: category(1), float64(4), int64(1), object(3)
# memory usage: 1.1+ MB
#                                           Name Platform  Year         Genre  \
# 0                                  '98 Koshien       PS  1998        Sports
# 1                   .hack//G.U. Vol.1//Rebirth      PS2  2006  Role-Playing
# 2                 .hack//G.U. Vol.2//Reminisce      PS2  2006  Role-Playing
# 3      .hack//G.U. Vol.2//Reminisce (jp sales)      PS2  2006  Role-Playing
# 4                .hack//G.U. Vol.3//Redemption      PS2  2007  Role-Playing
# ...                                        ...      ...   ...           ...
# 16592               thinkSMART: Chess for Kids       DS  2011          Misc
# 16593                             uDraw Studio      Wii  2010          Misc
# 16594             uDraw Studio: Instant Artist     X360  2011          Misc
# 16595             uDraw Studio: Instant Artist      Wii  2011          Misc
# 16597             ¡Shin Chan Flipa en colores!       DS  2007      Platform
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0         Magical Company      0.15      0.10      0.12         0.03
# 1      Namco Bandai Games      0.00      0.00      0.17         0.00
# 2      Namco Bandai Games      0.11      0.09      0.00         0.03
# 3      Namco Bandai Games      0.00      0.00      0.16         0.00
# 4      Namco Bandai Games      0.00      0.00      0.17         0.00
# ...                   ...       ...       ...       ...          ...
# 16592  Mentor Interactive      0.01      0.00      0.00         0.00
# 16593                 THQ      1.67      0.58      0.00         0.20
# 16594                 THQ      0.01      0.01      0.00         0.00
# 16595                 THQ      0.08      0.09      0.00         0.02
# 16597           505 Games      0.00      0.00      0.14         0.00
#
# [16274 rows x 9 columns]

# %% [markdown]
# ### **Eliminating inaccurate data**
# 1. Year
# * Year =< 0~22 은 앞에 20 이 전산오류로 빠진 것으로 추정
# > 해당 값들에 2000을 더한다.
# * Year > 0~22
# > 해당 값들에 1900을 더한다.
# * Year = 2020 데이터는 잘못된 데이터. 2020년에는 DS 단종되어서 게임이 나올 수 없다. 따라서 드랍한다.
# 2. Name
# * ~~sales 지역 별로 동일한 게임 값이 나누어져 있다. 이를 정리하여 합친다.

# %%
# Year 이상치 변경 함수
def year_normal(col):
  tmp = []

  for row in col:
    if row <= 22:
      tmp.append(row + 2000)
    elif  row <= 100 :
      tmp.append(row + 1900)
    else : tmp.append(row)

  return tmp

# %%
# 이상치 변경
df1['Year'] = year_normal(df1['Year'])
df1.drop(index = df1.query('Year==2020').index,axis = 0, inplace = True) # 2020 드랍

# 확인
df1['Year'].sort_values()  # 시간 범위는 1980 ~ 2017
# Out:
# 1526     1980
# 1466     1980
# 2891     1980
# 4758     1980
# 702      1980
#          ...
# 15124    2016
# 5473     2016
# 1544     2017
# 10307    2017
# 10306    2017
# Name: Year, Length: 16273, dtype: int64

# %% [markdown]
# ## Feature engineering
# 분석의 용이성을 위해 플랫폼에 대하여 묶어주는 컬럼을 하나 생성한다.

# %% [markdown]
# ### 1) 총계 피쳐 생성

# %%
# 1. Total feature 
Total = df1.iloc[:,5:9].sum(axis = 1)
df1['Total'] = Total

# %%
df1
# Out:
#                                           Name Platform  Year         Genre  \
# 0                                  '98 Koshien       PS  1998        Sports
# 1                   .hack//G.U. Vol.1//Rebirth      PS2  2006  Role-Playing
# 2                 .hack//G.U. Vol.2//Reminisce      PS2  2006  Role-Playing
# 3      .hack//G.U. Vol.2//Reminisce (jp sales)      PS2  2006  Role-Playing
# 4                .hack//G.U. Vol.3//Redemption      PS2  2007  Role-Playing
# ...                                        ...      ...   ...           ...
# 16592               thinkSMART: Chess for Kids       DS  2011          Misc
# 16593                             uDraw Studio      Wii  2010          Misc
# 16594             uDraw Studio: Instant Artist     X360  2011          Misc
# 16595             uDraw Studio: Instant Artist      Wii  2011          Misc
# 16597             ¡Shin Chan Flipa en colores!       DS  2007      Platform
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total
# 0         Magical Company      0.15      0.10      0.12         0.03   0.40
# 1      Namco Bandai Games      0.00      0.00      0.17         0.00   0.17
# 2      Namco Bandai Games      0.11      0.09      0.00         0.03   0.23
# 3      Namco Bandai Games      0.00      0.00      0.16         0.00   0.16
# 4      Namco Bandai Games      0.00      0.00      0.17         0.00   0.17
# ...                   ...       ...       ...       ...          ...    ...
# 16592  Mentor Interactive      0.01      0.00      0.00         0.00   0.01
# 16593                 THQ      1.67      0.58      0.00         0.20   2.45
# 16594                 THQ      0.01      0.01      0.00         0.00   0.02
# 16595                 THQ      0.08      0.09      0.00         0.02   0.19
# 16597           505 Games      0.00      0.00      0.14         0.00   0.14
#
# [16273 rows x 10 columns]

# %% [markdown]
# ### 2) Platform 타입 피쳐 생성
# 게임 기기의 타입은 크게 portable, console, pc로 나눠볼 수 있다.
# 분석의 용이성을 위해 새로운 피쳐를 추가한다.

# %%
# Console type 카테고리 추가
portable = ['PSV','PSP','3DS','DS','GBA','GB','WS']
console = ['PS4','PS3','PS2','PS','XOne','X360','XB','WiiU','Wii','GC','N64','SNES','SAT','2600','NES','DC','GEN','NG','3DO','TG16','PCFX','GG','SCD']
pc = ['PC']


df1['Type'] = df1['Platform']

# 각 value 값 변경
df1['Type'][df1['Type'].isin(console)] = 'Console'
df1['Type'][df1['Type'].isin(portable)] = 'Portable'
df1['Type'][df1['Type'].isin(pc)] = 'PC'

# 카테고리 데이터로 변경
df1['Type'].astype('category')
# Out:
# 0         Console
# 1         Console
# 2         Console
# 3         Console
# 4         Console
#            ...
# 16592    Portable
# 16593     Console
# 16594     Console
# 16595     Console
# 16597    Portable
# Name: Type, Length: 16273, dtype: category
# Categories (3, object): ['Console', 'PC', 'Portable']

# %% [markdown]
# ### 3) 필요없는 열 드랍
# 전치리 용이성을 위해 기존 Publisher,platform 열은 드랍한다.

# %%
# Platform, Publiser 드랍
#df1.drop(['Platform'],axis = 1, inplace = True)

# %% [markdown]
# ### 4) Column 순서 재정렬

# %%
# 컬럼 순서 보기 좋게 변경
df1 = df1[['Name','Type', 'Genre', 'Year','NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Total','Platform','Publisher']]

df1.columns
# Out:
# Index(['Name', 'Type', 'Genre', 'Year', 'NA_Sales', 'EU_Sales', 'JP_Sales',
#        'Other_Sales', 'Total', 'Platform', 'Publisher'],
#       dtype='object')

# %%
df1
# Out:
#                                           Name      Type         Genre  Year  \
# 0                                  '98 Koshien   Console        Sports  1998
# 1                   .hack//G.U. Vol.1//Rebirth   Console  Role-Playing  2006
# 2                 .hack//G.U. Vol.2//Reminisce   Console  Role-Playing  2006
# 3      .hack//G.U. Vol.2//Reminisce (jp sales)   Console  Role-Playing  2006
# 4                .hack//G.U. Vol.3//Redemption   Console  Role-Playing  2007
# ...                                        ...       ...           ...   ...
# 16592               thinkSMART: Chess for Kids  Portable          Misc  2011
# 16593                             uDraw Studio   Console          Misc  2010
# 16594             uDraw Studio: Instant Artist   Console          Misc  2011
# 16595             uDraw Studio: Instant Artist   Console          Misc  2011
# 16597             ¡Shin Chan Flipa en colores!  Portable      Platform  2007
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total Platform  \
# 0          0.15      0.10      0.12         0.03   0.40       PS
# 1          0.00      0.00      0.17         0.00   0.17      PS2
# 2          0.11      0.09      0.00         0.03   0.23      PS2
# 3          0.00      0.00      0.16         0.00   0.16      PS2
# 4          0.00      0.00      0.17         0.00   0.17      PS2
# ...         ...       ...       ...          ...    ...      ...
# 16592      0.01      0.00      0.00         0.00   0.01       DS
# 16593      1.67      0.58      0.00         0.20   2.45      Wii
# 16594      0.01      0.01      0.00         0.00   0.02     X360
# 16595      0.08      0.09      0.00         0.02   0.19      Wii
# 16597      0.00      0.00      0.14         0.00   0.14       DS
#
#                 Publisher
# 0         Magical Company
# 1      Namco Bandai Games
# 2      Namco Bandai Games
# 3      Namco Bandai Games
# 4      Namco Bandai Games
# ...                   ...
# 16592  Mentor Interactive
# 16593                 THQ
# 16594                 THQ
# 16595                 THQ
# 16597           505 Games
#
# [16273 rows x 11 columns]

# %%
# 컬럼이름 재정의
#df_str = df1.rename(columns = {'NA_Sales':'North_America', 'EU_Sales':'EU', 'JP_Sales':'JP','Other_Sales': 'Other'})

# Melt 로 sales 데이터 병합
#id = ['Name', 'Platform', 'Year', 'Genre', 'Publisher']
#value = ['North_America', 'EU', 'JP', 'Other']
#var = 'Region'
#val_name = 'Sales'

#df_str = pd.melt(df_str, id_vars = id, value_vars = value, var_name = var, value_name = val_name)

# %% [markdown]
# ### 5) 이름 중복되는 데이터 처리

# %% [markdown]
# 이름에 중복되는 데이터들의 경우, (~~sales US sales 등) 지역 별 데이터가 나누어진 것으로 join 한다.

# %%
# 이름 중복값 찾기 함수 선언
def error_finder(df):
  #regex = re.compile('\(\D+\)')
  pattern = re.compile('sales')
  match2 = df['Name'].str.contains(pat = pattern)

  error = df['Name'][match2].sort_values()
  
  return error

# %%
# 이상한 이름 각각 나누기
dupi = error_finder(df1).str.split(r"\(",expand = True)[0]
dupi.replace('\s+$', '', regex=True, inplace=True) #공백제거

mapi = error_finder(df1)

# %%
# Name에서 괄호안에 sales 들어간 값 모두 제거
# problems = df1[df1['Name'].isin(dupi.unique()) | df1['Name'].isin(mapi)]
#problems.replace('\s\([A-z].+',"", regex = True)

df1 = df1.replace('\s\([A-z].+',"", regex = True).groupby(['Name','Type','Platform','Publisher']).agg({'Genre':'first','Year':min,'NA_Sales':sum,'EU_Sales':sum,'JP_Sales':sum,'Other_Sales':sum,'Total':sum}) # 총 레코드의 개수는 12770개

# %%
df1
# Out:
#                                                                            Genre  \
# Name                          Type     Platform Publisher
# '98 Koshien                   Console  PS       Magical Company           Sports
# .hack//G.U. Vol.1//Rebirth    Console  PS2      Namco Bandai Games  Role-Playing
# .hack//G.U. Vol.2//Reminisce  Console  PS2      Namco Bandai Games  Role-Playing
# .hack//G.U. Vol.3//Redemption Console  PS2      Namco Bandai Games  Role-Playing
# .hack//Infection Part 1       Console  PS2      Atari               Role-Playing
# ...                                                                          ...
# thinkSMART: Chess for Kids    Portable DS       Mentor Interactive          Misc
# uDraw Studio                  Console  Wii      THQ                         Misc
# uDraw Studio: Instant Artist  Console  Wii      THQ                         Misc
#                                        X360     THQ                         Misc
# ¡Shin Chan Flipa en colores!  Portable DS       505 Games               Platform
#
#                                                                     Year  \
# Name                          Type     Platform Publisher
# '98 Koshien                   Console  PS       Magical Company     1998
# .hack//G.U. Vol.1//Rebirth    Console  PS2      Namco Bandai Games  2006
# .hack//G.U. Vol.2//Reminisce  Console  PS2      Namco Bandai Games  2006
# .hack//G.U. Vol.3//Redemption Console  PS2      Namco Bandai Games  2007
# .hack//Infection Part 1       Console  PS2      Atari               2002
# ...                                                                  ...
# thinkSMART: Chess for Kids    Portable DS       Mentor Interactive  2011
# uDraw Studio                  Console  Wii      THQ                 2010
# uDraw Studio: Instant Artist  Console  Wii      THQ                 2011
#                                        X360     THQ                 2011
# ¡Shin Chan Flipa en colores!  Portable DS       505 Games           2007
#
#                                                                     NA_Sales  \
# Name                          Type     Platform Publisher
# '98 Koshien                   Console  PS       Magical Company         0.15
# .hack//G.U. Vol.1//Rebirth    Console  PS2      Namco Bandai Games      0.00
# .hack//G.U. Vol.2//Reminisce  Console  PS2      Namco Bandai Games      0.11
# .hack//G.U. Vol.3//Redemption Console  PS2      Namco Bandai Games      0.00
# .hack//Infection Part 1       Console  PS2      Atari                   0.49
# ...                                                                      ...
# thinkSMART: Chess for Kids    Portable DS       Mentor Interactive      0.01
# uDraw Studio                  Console  Wii      THQ                     1.67
# uDraw Studio: Instant Artist  Console  Wii      THQ                     0.08
#                                        X360     THQ                     0.01
# ¡Shin Chan Flipa en colores!  Portable DS       505 Games               0.00
#
#                                                                     EU_Sales  \
# Name                          Type     Platform Publisher
# '98 Koshien                   Console  PS       Magical Company         0.10
# .hack//G.U. Vol.1//Rebirth    Console  PS2      Namco Bandai Games      0.00
# .hack//G.U. Vol.2//Reminisce  Console  PS2      Namco Bandai Games      0.09
# .hack//G.U. Vol.3//Redemption Console  PS2      Namco Bandai Games      0.00
# .hack//Infection Part 1       Console  PS2      Atari                   0.38
# ...                                                                      ...
# thinkSMART: Chess for Kids    Portable DS       Mentor Interactive      0.00
# uDraw Studio                  Console  Wii      THQ                     0.58
# uDraw Studio: Instant Artist  Console  Wii      THQ                     0.09
#                                        X360     THQ                     0.01
# ¡Shin Chan Flipa en colores!  Portable DS       505 Games               0.00
#
#                                                                     JP_Sales  \
# Name                          Type     Platform Publisher
# '98 Koshien                   Console  PS       Magical Company         0.12
# .hack//G.U. Vol.1//Rebirth    Console  PS2      Namco Bandai Games      0.17
# .hack//G.U. Vol.2//Reminisce  Console  PS2      Namco Bandai Games      0.16
# .hack//G.U. Vol.3//Redemption Console  PS2      Namco Bandai Games      0.17
# .hack//Infection Part 1       Console  PS2      Atari                   0.26
# ...                                                                      ...
# thinkSMART: Chess for Kids    Portable DS       Mentor Interactive      0.00
# uDraw Studio                  Console  Wii      THQ                     0.00
# uDraw Studio: Instant Artist  Console  Wii      THQ                     0.00
#                                        X360     THQ                     0.00
# ¡Shin Chan Flipa en colores!  Portable DS       505 Games               0.14
#
#                                                                     Other_Sales  \
# Name                          Type     Platform Publisher
# '98 Koshien                   Console  PS       Magical Company            0.03
# .hack//G.U. Vol.1//Rebirth    Console  PS2      Namco Bandai Games         0.00
# .hack//G.U. Vol.2//Reminisce  Console  PS2      Namco Bandai Games         0.03
# .hack//G.U. Vol.3//Redemption Console  PS2      Namco Bandai Games         0.00
# .hack//Infection Part 1       Console  PS2      Atari                      0.13
# ...                                                                         ...
# thinkSMART: Chess for Kids    Portable DS       Mentor Interactive         0.00
# uDraw Studio                  Console  Wii      THQ                        0.20
# uDraw Studio: Instant Artist  Console  Wii      THQ                        0.02
#                                        X360     THQ                        0.00
# ¡Shin Chan Flipa en colores!  Portable DS       505 Games                  0.00
#
#                                                                     Total
# Name                          Type     Platform Publisher
# '98 Koshien                   Console  PS       Magical Company      0.40
# .hack//G.U. Vol.1//Rebirth    Console  PS2      Namco Bandai Games   0.17
# .hack//G.U. Vol.2//Reminisce  Console  PS2      Namco Bandai Games   0.39
# .hack//G.U. Vol.3//Redemption Console  PS2      Namco Bandai Games   0.17
# .hack//Infection Part 1       Console  PS2      Atari                1.26
# ...                                                                   ...
# thinkSMART: Chess for Kids    Portable DS       Mentor Interactive   0.01
# uDraw Studio                  Console  Wii      THQ                  2.45
# uDraw Studio: Instant Artist  Console  Wii      THQ                  0.19
#                                        X360     THQ                  0.02
# ¡Shin Chan Flipa en colores!  Portable DS       505 Games            0.14
#
# [16165 rows x 7 columns]

# %%
# 멀티 인덱스 없애기
df1.reset_index(inplace = True)

# %% [markdown]
# ## 힘들게 정리한 데이터 저장

# %%
df1.to_csv('Games_cleaned.csv', index = False)
#df_str.to_csv('Games_structured.csv', index = False)

# %% [markdown]
# **EDA**
# ======
# **확인할 것**
# 1. 기술통계량
# 2. 시각화

# %% [markdown]
# ## **역대 모든 범위**
# 분석 범위: 1980 - 2017
# 역대 모든 범위를 통해 총괄적인 흐름을 본다.

# %% [markdown]
# ## **최근 3개년 추세**
# 2014~2016 기간의 게임이 최근의 트랜드를 반영한다.
# 따라서 다음 게임을 기획할 때 필요한 주요 분석 대상은 해당 기간으로 한다.
# 다만 역대 모든 범위를 먼저 기본적으로 분석한 후 위에서 데이터 범위를 제한하여 하위 분석이 돌아가도록 한다.

# %% [markdown]
# ### 1. Descriptive statistics

# %%
df = pd.read_csv('Games_cleaned.csv')

df = df.query('Year <2017 & Year >= 2014') # 3개년 추세 분석을 위한 데이터 제한

print(df.shape)
df.describe() # 북아메리카와 유럽에서의 판매량이 다수를 차지한다.
# Out:
# (1537, 11)
#               Year     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count  1537.000000  1537.000000  1537.000000  1537.000000  1537.000000
# mean   2014.845153     0.166851     0.162225     0.056337     0.050371
# std       0.760836     0.440823     0.453319     0.212547     0.148255
# min    2014.000000     0.000000     0.000000     0.000000     0.000000
# 25%    2014.000000     0.000000     0.000000     0.000000     0.000000
# 50%    2015.000000     0.020000     0.030000     0.010000     0.010000
# 75%    2015.000000     0.130000     0.130000     0.050000     0.040000
# max    2016.000000     5.770000     6.060000     3.180000     2.310000
#
#              Total
# count  1537.000000
# mean      0.435784
# std       1.040720
# min       0.010000
# 25%       0.030000
# 50%       0.100000
# 75%       0.370000
# max      14.240000

# %%
# 총 게임의 개수
df.Name.nunique()
# Out:
# 867

# %%
df.head()
# Out:
#                           Name      Type Platform        Publisher      Genre  \
# 35    12-Sai. Honto no Kimochi  Portable      3DS         Happinet  Adventure
# 36       12-Sai. Koisuru Diary  Portable      3DS         Happinet  Adventure
# 65  2014 FIFA World Cup Brazil   Console      PS3  Electronic Arts     Sports
# 66  2014 FIFA World Cup Brazil   Console     X360  Electronic Arts     Sports
# 77      3DS Classic Collection  Portable      3DS             Sega       Misc
#
#     Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total
# 35  2014      0.00      0.00      0.07         0.00   0.07
# 36  2016      0.00      0.00      0.04         0.00   0.04
# 65  2014      0.15      0.39      0.01         0.16   0.71
# 66  2014      0.14      0.28      0.00         0.04   0.46
# 77  2016      0.02      0.00      0.00         0.00   0.02

# %% [markdown]
# #### 시장 규모

# %%
# 시장 규모
region = df.loc[:,'NA_Sales':'Other_Sales'].sum()
total = df.Total.sum()

# Market Size
plt.pie(round(region/total*100, 1),labels= region.index, autopct='%.1f%%')
plt.title('Market Portion')
# Out:
# Text(0.5, 1.0, 'Market Portion')

# %% [markdown]
# **Point!**
# 시장 규모는 미국 > 유럽 > 일본 > 기타 지역 순이다.
#
# 데이터에 outlier가 다소 존재하여 대푯값은 이상치에 로버스트한 중앙값으로 설정한다.

# %% [markdown]
# #### 장르에 따른 평균 판매량

# %%
df.groupby(by = 'Genre').mean().sort_values(by = 'Total', ascending = False).head(5)
# Out:
#                      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales     Total
# Genre
# Shooter       2014.867257  0.610177  0.510973  0.038761     0.170000  1.329912
# Sports        2014.890323  0.276452  0.275806  0.020000     0.090710  0.662968
# Platform      2015.000000  0.185588  0.185588  0.078235     0.050588  0.500000
# Fighting      2014.844828  0.208448  0.113793  0.107414     0.049310  0.478966
# Role-Playing  2014.755981  0.135407  0.119856  0.134211     0.036699  0.426172

# %%
df.groupby(by = 'Genre').sum().sort_values(by = 'Total', ascending = False).head(5)
# Out:
#                  Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales   Total
# Genre
# Action        1124303     66.43     70.73     27.85        22.10  187.11
# Shooter        227680     68.95     57.74      4.38        19.21  150.28
# Sports         312308     42.85     42.75      3.10        14.06  102.76
# Role-Playing   421084     28.30     25.05     28.05         7.67   89.07
# Misc           197447     14.46     12.67      5.27         4.14   36.54

# %% [markdown]
# **장르별 기술 통계량**
# * 평균적으로는 Shooter, Sports, Fighting 장르가 높은 점유율을 기록했다.
# * 반면, 누적 판매량은 Action, Shooter, Sports 장르가 상위 점유율을 보였다.

# %% [markdown]
# #### 지역 별 장르 점유율
# > 점유율이므로 누적 판매량을 기준으로 집계한다.

# %%
# 북아메리카에서 선호하는 장르
Total_sum = df.Total.sum()

df_genre_NA = df.groupby(by = 'Genre').sum().sort_values(by = 'NA_Sales', ascending = False)['NA_Sales']
# df_genre_NA = round(df_genre_NA/Total_sum*100,1)

# %%
# 유럽에서 선호하는 장르
df_genre_EU = df.groupby(by = 'Genre').sum().sort_values(by = 'EU_Sales', ascending = False)['EU_Sales']
# df_genre_EU = round(df_genre_EU/Total_sum*100,1) # 유럽과 북미의 장르 선호도는 비슷하게 나타났다. (다만 가설 검증 필요)

# %%
# 일본에서 선호하는 장르
df_genre_JP = df.groupby(by = 'Genre').sum().sort_values(by = 'JP_Sales', ascending = False)['JP_Sales']
#df_genre_JP = round(df_genre_JP/Total_sum*100,1) # 명확히 롤플레잉 게임이 우위를 점한다. 북미, 유럽에서 높은 점유율을 보이던 슈팅 게임은 일본에서는 통하지 않았다.

# %%
# 기타 지역에서 선호하는 장르
df_genre_Ot = df.groupby(by = 'Genre').sum().sort_values(by = 'Other_Sales', ascending = False)['Other_Sales']
#df_genre_Ot = round(df_genre_Ot/Total_sum*100,1) # 기타 지역은 일본을 제외한 나머지 지역과 비슷한 장르 분포를 보인다.

# %%
# 추후 가설 검증을 위해 저장
Genre_df = pd.concat([df_genre_NA,df_genre_EU, df_genre_JP,df_genre_Ot], axis = 1)
Genre_df
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Shooter          68.95     57.74      4.38        19.21
# Action           66.43     70.73     27.85        22.10
# Sports           42.85     42.75      3.10        14.06
# Role-Playing     28.30     25.05     28.05         7.67
# Misc             14.46     12.67      5.27         4.14
# Fighting         12.09      6.60      6.23         2.86
# Racing            8.16     13.58      1.75         2.81
# Platform          6.31      6.31      2.66         1.72
# Adventure         5.04      5.86      3.37         1.64
# Simulation        2.35      6.04      2.25         0.90
# Strategy          0.84      1.52      0.75         0.20
# Puzzle            0.67      0.49      0.93         0.11

# %% [markdown]
# **Insight**
# - 유럽과 북미의 장르 선호도는 비슷하게 나타났다. (다만 가설 검증 필요)
# - 일본에서는 명확히 롤플레잉 게임이 우위를 점한다. 북미, 유럽에서 높은 점유율을 보이던 슈팅 게임은 일본에서는 통하지 않았다.
# - 기타 지역은 일본을 제외한 나머지 지역과 비슷한 장르 분포를 보인다.
# - Action 게임의 경우 지역 상관없이 항상 상위 3개 판매량을 보였다.
# > 4개 집단의 차이 검정을 위해 카이제곱 분석이 필요할 것으로 보인다.

# %% [markdown]
# ### 2. Visualization
# 1) 플랫폼 선호도
# - 지역별
# - 연도별

# %% [markdown]
# #### 지역 별 장르 선호도

# %%
plt.figure(figsize = (10, 8),dpi=80)

ax = sns.barplot(x=Genre_df.index, y="NA_Sales", data=Genre_df)

plt.title('Top sales genre in North America (2014~2016)')
plt.ylim(0,80)
# Out:
# (0.0, 80.0)

# %%
plt.figure(figsize = (10, 8),dpi=80)

ax = sns.barplot(x=Genre_df.index, y="JP_Sales", data=Genre_df)

plt.title('Top sales genre in Japan (2014~2016)')
plt.ylim(0,80)
# Out:
# (0.0, 80.0)

# %%
plt.figure(figsize = (10, 8),dpi=80)

ax = sns.barplot(x=Genre_df.index, y="EU_Sales", data=Genre_df)

plt.title('Top sales genre in EU (2014~2016)')
plt.ylim(0,80)
# Out:
# (0.0, 80.0)

# %%
plt.figure(figsize = (10, 8),dpi=80)

ax = sns.barplot(x=Genre_df.index, y="Other_Sales", data=Genre_df)

plt.title('Top sales genre in Other (2014~2016)')
plt.ylim(0,80)
# Out:
# (0.0, 80.0)

# %%
# Platform Type 별 지역 점유율

plt.style.use('seaborn')

# Total
plt.subplot(2, 3, 1)
pie1 = df.groupby(by = 'Type')['Total'].sum()

plt.pie(x = pie1, labels = pie1.index, autopct='%.1f%%');
plt.title('Total')

# NA
plt.subplot(2, 3, 2)
pie2 = df.groupby(by = 'Type')['NA_Sales'].sum()

plt.pie(x = pie2, labels = pie2.index, autopct='%.1f%%');
plt.title('NA')

# EU
plt.subplot(2, 3, 3)
pie3 = df.groupby(by = 'Type')['EU_Sales'].sum()

plt.pie(x = pie3, labels = pie3.index, autopct='%.1f%%');
plt.title('EU')

# JP
plt.subplot(2, 3, 4)
pie4 = df.groupby(by = 'Type')['JP_Sales'].sum()

plt.pie(x = pie4, labels = pie4.index, autopct='%.1f%%');
plt.title('JP')

# Others
plt.subplot(2, 3, 5)
pie4 = df.groupby(by = 'Type')['Other_Sales'].sum()

plt.pie(x = pie4, labels = pie4.index, autopct='%.1f%%');
plt.title('Other')

plt.show()

# %% [markdown]
# 💡 **Insight**
# - 일본을 제외하고 콘솔의 점유율이 압도적으로 높다.
# - 이는 닌텐도 DS와 같은 휴대용 게임 기기가 일본에서 특히 발달했다는 것을 알 수 있다.
#
# -> 지역 별 콘솔 기기의 선호도에 차이가 나는지 여부에 대한 가설 검증이 가능하다. 뒤이어 계속

# %% [markdown]
# #### **플랫폼 선호도 추세**

# %%
# 연도별 플랫폼 점유율
plt.figure(figsize = (14, 6),dpi=80)

a = df.groupby(by = ['Type','Year']).sum()

sns.lineplot(data=a, x = 'Year', y = 'Total', hue = 'Type')
plt.title('Game trand over years')
plt.xticks(df['Year'].unique())
#plt.xlim(1990,2000)
#plt.ylim()
plt.show()

# %%
df.query('Year == 2005').groupby(by = 'Type').sum()
# Out:
# Empty DataFrame
# Columns: [Year, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Total]
# Index: []

# %%
df.query('Year == 2005').sort_values(by = 'Total', ascending = False).head(5)
# Out:
# Empty DataFrame
# Columns: [Name, Type, Platform, Publisher, Genre, Year, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Total]
# Index: []

# %% [markdown]
# 💡 **Insight**
# - 연도 별로도, 콘솔이 지속적으로 우위를 점하고 있다.
# - 그러나, 2005년의 경우 휴대용 게임 기기가 이를 바짝 추격했었는데, 이는 2005년 닌텐도의 역대 최고 인기를 보여주었던 타이틀이 발매되었기 때문인 것으로 분석된다.
#   * 1위 닌텐독스 : 24M
#   * 2위 마리오카트 : 23M
# - 또한, 대체로 2005년~2010년 사이 비디오 게임 시장이 붐을 이루었지만 2010년도를 기점으로 기종 상관 없이 2017년까지 판매량이 지속적으로 감소하고있음을 알 수 있다.
#   * 이는 2010년대 스마트폰의 발달로 점유율이 모바일 게임으로 넘어가고 있지 않나 조심스럽게 추측해본다.

# %% [markdown]
# #### 장르 별 추세

# %%
# 지역별 장르 추세 그래프 그리는 함수 정의
def chart_maker(Region):
  plt.figure(figsize = (14, 6),dpi=80)

  a = df.groupby(by = ['Genre','Year'], as_index=False).sum().sort_values(by = Region, ascending = False)

  sns.lineplot(data=a, x = 'Year', y = Region, hue = 'Genre')
  plt.title(f'Popular {Region} genre over years')
  plt.xticks(df['Year'].unique())
  return plt.show()

# %%
# df.groupby(by = ['Genre','Year'],as_index=False).sum().sort_values(by = 'Genre', ascending = True)

# %%
chart_maker('Total') # 지역 값 컬럼 이름 넣으면 차트 만들어줌

# %% [markdown]
# #### Stacked bar chart - 장르별

# %%
#df.set_index('Year').plot(kind='bar', stacked=True, color=['steelblue', 'red'])

# %%
data = df.groupby(by = ['Genre','Year'], as_index=False).sum().sort_values(by = 'Total', ascending = False)[['Genre','Year','Total']]

# %%
data.groupby(by = ['Genre']).sum().sort_values(by = 'Total', ascending = False).index
# Out:
# Index(['Action', 'Shooter', 'Sports', 'Role-Playing', 'Misc', 'Fighting',
#        'Racing', 'Platform', 'Adventure', 'Simulation', 'Strategy', 'Puzzle'],
#       dtype='object', name='Genre')

# %%
# 차트를 그리려면 Year로 피봇을 해야함.
pivot = pd.pivot_table(data,
                       index = 'Year',  # 행 위치에 들어갈 열
                       columns = 'Genre', # 열 위치에 들어갈 열
                       values = 'Total', # 데이터로 사용할 열
                       aggfunc = sum)    # 데이터 집계함수
df_pivot = pivot.fillna(0)

# %%
df_pivot
# Out:
# Genre  Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# Year
# 2014    99.01       6.09     16.15  23.73      8.87    1.51   16.71
# 2015    68.25       8.01      7.78  11.66      6.05    0.69    7.92
# 2016    19.85       1.81      3.85   1.15      2.08    0.00    1.67
#
# Genre  Role-Playing  Shooter  Simulation  Sports  Strategy
# Year
# 2014          45.89    65.99        5.54   46.64      0.97
# 2015          36.43    66.12        5.61   41.49      1.82
# 2016           6.75    18.17        0.39   14.63      0.52

# %%
# Plot stacked bar chart
import matplotlib as mpl
plt.style.use('ggplot') # 그래프 스타일

# Variables
index = pivot.index
values = [pivot.iloc[:,i] for i in range(pivot.shape[1])]
plot_title = 'Genre preference over year'
title_size = 18
subtitle = 'ing'
x_label = 'Year'
labels = pivot.columns

# Create subplots and set a colormap
fig, ax = plt.subplots(figsize = (14,8), facecolor=(.94, .94, .94)) # 그래프 크기
mpl.pyplot.plasma() # set colormap

for i in range(pivot.shape[1]):
  ax.barh(index, values[i], label = labels[i]) # 가로 바 차트

plt.tight_layout() #subplot fit 하기


#set title, fontsize, position
title = plt.title(plot_title, fontsize=title_size)
title.set_position([.33, 1])
plt.subplots_adjust(top=0.9, bottom=0.1)

# color
ax.grid(zorder=0)

# def gradientbars(bars):
#     grad = np.atleast_2d(np.linspace(0,1,256))
#     ax = bars[0].axes
#     lim = ax.get_xlim()+ax.get_ylim()
#     for bar in bars:
#         bar.set_zorder(1)
#         bar.set_facecolor('none')
#         x,y = bar.get_xy()
#         w, h = bar.get_width(), bar.get_height()
#         ax.imshow(grad, extent=[x+w, x, y, y+h], aspect='auto', zorder=1)
#     ax.axis(lim)
    
# gradientbars(bar)

ax.legend()

plt.show()

# %% [markdown]
# ### Inference statistics
# **두 카테고리 변수이므로 카이제곱 검정을 사용한다**
#  - 지역별 장르 선호도 차이는 통계적으로 유의한가?
#  - 지역별 플랫폼 선호도 차이는 통계적으로 유의한가?

# %% [markdown]
# ### 1) 지역에 따른 선호하는 게임장르는 다른가?
# - 카이제곱 검정
# - 귀무가설: 지역에 따른 선호하는 게임장르는 차이가 없다.
# - 대립가설: 지역에 따른 선호하는 게임장르는 차이가 있다.
#
# [독립성 검정]
# - 귀무가설: 지역의 종류는 장르 별 판매량과 관계가 없다.(독립이다)
# - 대립가설 : 지역의 종류는 장르 별 판매량과 관계가 있다.(독립이 아니다)

# %%
# 카이제곱 검정을 통한 가설검정
from scipy.stats import chi2_contingency

chi = chi2_contingency(Genre_df, correction = True)
print(f'X^2 statistics : {round(chi[0],2)}\np-value : {round(chi[1],4)}')
# Out:
# X^2 statistics : 63.52
# p-value : 0.0011

# %% [markdown]
# **유의확률이 0.000 이므로 유의수준 0.05에서 지역 판매량과 장르 간에는 통계적으로 유의미한 관련성이 있는 것으로 나타났다.**

# %%
# 그럼 미주와 유럽은?
chi = chi2_contingency(Genre_df.iloc[:,0:2], correction = True)
print(f'X^2 statistics : {round(chi[0],2)}\np-value : {round(chi[1],4)}') # 미주와 유럽은 장르에 따른 지역 판매량에 차이가 없음
# Out:
# X^2 statistics : 6.22
# p-value : 0.8585

# %%
Genre_df.loc[:,['NA_Sales','JP_Sales']]
# Out:
#               NA_Sales  JP_Sales
# Genre
# Shooter          68.95      4.38
# Action           66.43     27.85
# Sports           42.85      3.10
# Role-Playing     28.30     28.05
# Misc             14.46      5.27
# Fighting         12.09      6.23
# Racing            8.16      1.75
# Platform          6.31      2.66
# Adventure         5.04      3.37
# Simulation        2.35      2.25
# Strategy          0.84      0.75
# Puzzle            0.67      0.93

# %%
# 미주 X 일본
chi = chi2_contingency(Genre_df.loc[:,['NA_Sales','JP_Sales']], correction = False)
chi[:-1]
exp = pd.DataFrame(chi[3])
chi[:-1]
# Out:
# (46.48924799179154, 2.6491290311494604e-06, 11)

# %%
# 의심되어서 직접 구해봄
obs = Genre_df.loc[:,['NA_Sales','JP_Sales']]
x_2 = []

for i in range(len(obs)):
  tmp = (obs.iloc[i,0] - exp.iloc[i,0])**2 / exp.iloc[i,0]
  x_2.append(tmp)
  tmp = (obs.iloc[i,1] - exp.iloc[i,1])**2 / exp.iloc[i,1]
  x_2.append(tmp)
  
print('X:',sum(x_2))
# Out:
# X: 46.48924799179152

# %% [markdown]
# ### 2) 지역에 따른 선호하는 게임플랫폼은 다른가?
# [독립성 검정]
# 귀무가설: 지역의 종류는 Type 별 판매량과 관계가 없다.(독립이다)
# 대립가설 : 지역의 종류는 Type 별 판매량과 관계가 있다.(독립이 아니다)

# %%
df_type = df.groupby(by = 'Type').sum().loc[:,['NA_Sales',	'EU_Sales',	'JP_Sales',	'Other_Sales']]
df_type
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Type
# Console     227.37    214.84     31.60        69.81
# PC            6.44     15.49      0.00         2.03
# Portable     22.64     19.01     54.99         5.58

# %%
# 카이제곱 검정을 통한 가설검정

chi = chi2_contingency(df_type, correction = True)
chi#전체 지역 간에는 차이가 없다고 나타남.
print(f'X^2 statistics : {round(chi[0],2)}\np-value : {round(chi[1],9)}')
# Out:
# X^2 statistics : 185.39
# p-value : 0.0

# %% [markdown]
# 유의확률이 0.0 이므로 유의수준 0.05에서 지역 판매량과 플랫폼 간에는 통계적으로 유의미한 관련성이 있는 것으로 나타났다.

# %%
df_Platform = df.groupby(by = 'Platform').sum().loc[:,['NA_Sales',	'EU_Sales',	'JP_Sales',	'Other_Sales']]
df_Platform
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Platform
# 3DS          18.68     13.95     41.06         2.95
# DS            0.02      0.00      0.00         0.00
# PC            6.44     15.49      0.00         2.03
# PS3          21.28     28.80     11.00        10.62
# PS4          85.71    111.95     13.08        40.25
# PSP           0.00      0.00      0.36         0.00
# PSV           3.94      5.06     13.57         2.63
# Wii           2.39      3.12      0.00         0.48
# WiiU         19.04     12.38      7.12         3.65
# X360         27.56     18.25      0.08         4.39
# XOne         71.39     40.34      0.32        10.42

# %%
# 카이제곱 검정을 통한 가설검정

chi = chi2_contingency(df_type, correction = True)
chi[:-1] #전체 지역 간에는 차이가 없다고 나타남.
# Out:
# (185.39289141667234, 2.426111973288411e-37, 6)

# %%
# 박스플롯 그려보자.
ax = df.iloc[:,6:9].plot.box()
ax; # 이렇게 보아서는 차이를 모르겠다....

# %% [markdown]
# 2014-16년도 출고량 상위 10개 게임에 대한 분석
# ======

# %%
df.query('Year >=2014').sort_values(by = 'Total', ascending = False).head(10).reset_index(drop = True)
# Out:
#                                         Name      Type Platform  \
# 0                  Call of Duty: Black Ops 3   Console      PS4
# 1                         Grand Theft Auto V   Console      PS4
# 2  Pokemon Omega Ruby/Pokemon Alpha Sapphire  Portable      3DS
# 3                                    FIFA 16   Console      PS4
# 4               Star Wars Battlefront (2015)   Console      PS4
# 5             Call of Duty: Advanced Warfare   Console      PS4
# 6        Super Smash Bros. for Wii U and 3DS  Portable      3DS
# 7                  Call of Duty: Black Ops 3   Console     XOne
# 8                                  Fallout 4   Console      PS4
# 9                               Mario Kart 8   Console     WiiU
#
#               Publisher         Genre  Year  NA_Sales  EU_Sales  JP_Sales  \
# 0            Activision       Shooter  2015      5.77      5.81      0.35
# 1  Take-Two Interactive        Action  2014      3.80      5.81      0.36
# 2              Nintendo  Role-Playing  2014      4.23      3.37      3.08
# 3       Electronic Arts        Sports  2015      1.11      6.06      0.06
# 4       Electronic Arts       Shooter  2015      2.93      3.29      0.22
# 5            Activision       Shooter  2014      2.80      3.30      0.14
# 6              Nintendo      Fighting  2014      3.24      1.35      2.42
# 7            Activision       Shooter  2015      4.52      2.09      0.01
# 8    Bethesda Softworks  Role-Playing  2015      2.47      3.15      0.24
# 9              Nintendo        Racing  2014      3.13      2.07      1.27
#
#    Other_Sales  Total
# 0         2.31  14.24
# 1         2.02  11.99
# 2         0.65  11.33
# 3         1.26   8.49
# 4         1.23   7.67
# 5         1.37   7.61
# 6         0.43   7.44
# 7         0.67   7.29
# 8         1.10   6.96
# 9         0.49   6.96

# %%
df.query('Year >=2016').sort_values(by = 'Total', ascending = False).head(10).reset_index(drop = True)
# Out:
#                          Name     Type Platform                    Publisher  \
# 0                     FIFA 17  Console      PS4              Electronic Arts
# 1  Uncharted 4: A Thief's End  Console      PS4  Sony Computer Entertainment
# 2   Tom Clancy's The Division  Console      PS4                      Ubisoft
# 3             Far Cry: Primal  Console      PS4                      Ubisoft
# 4   Tom Clancy's The Division  Console     XOne                      Ubisoft
# 5                   Overwatch  Console      PS4                   Activision
# 6                No Man's Sky  Console      PS4                  Hello Games
# 7              Dark Souls III  Console      PS4           Namco Bandai Games
# 8                     FIFA 17  Console     XOne              Electronic Arts
# 9                 Doom (2016)  Console      PS4           Bethesda Softworks
#
#           Genre  Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total
# 0        Sports  2016      0.28      3.75      0.06         0.69   4.78
# 1       Shooter  2016      1.30      2.07      0.18         0.65   4.20
# 2       Shooter  2016      1.28      1.61      0.15         0.57   3.61
# 3        Action  2016      0.59      1.16      0.06         0.33   2.14
# 4       Shooter  2016      1.20      0.62      0.00         0.18   2.00
# 5       Shooter  2016      0.64      0.68      0.14         0.26   1.72
# 6        Action  2016      0.58      0.74      0.02         0.26   1.60
# 7  Role-Playing  2016      0.58      0.44      0.33         0.21   1.56
# 8        Sports  2016      0.17      1.26      0.00         0.10   1.53
# 9       Shooter  2016      0.49      0.66      0.02         0.22   1.39
